# %%
dbutils.notebook.run("/Workspace/Users/shashwat.sharma280990@gmail.com/DBexample/exercises/01_intro",1200,{"file_path_value":"/databricks-datasets/Rdatasets/data-001/csv/ggplot2/movies.csv","file_format_value":"csv"})
